# %%
import sqlalchemy as db
import pandas as pd
import datetime as date
import os
from dotenv import load_dotenv

# %% [markdown]
# Load the **environment**

# %%
load_dotenv()
DATABASE = os.getenv('DATABASE')
DATABASE_SERVER = os.getenv('DATABASE_SERVER')

# %% [markdown]
# ##### Problems loading the driver
# url_object = db.engine.URL.create(
#     drivername='ODBC Driver 17 for SQL Server',
#     username='user',
#     password='pass',
#     host=DATABASE_SERVER,
#     database=DATABASE
# )
# engine = db.create_engine(url_object)
# conn = engine.connect()
# metadata = db.MetaData()

# %%
# Creating the engine connection using another type of string with the driver at the end
# Works without the port, if i dont provide username and password, uses my windows credentials
connection_str = f'mssql://{DATABASE_SERVER}/{DATABASE}?driver=ODBC Driver 17 for SQL Server'
engine = db.create_engine(connection_str)
conn = engine.connect()
metadata = db.MetaData()

# %%
# Test a simple select
result = conn.execute(db.text('select * from departments'))

# %%
# Check output
result.fetchall()
# Out:
# [(1, 'Engineering', 'Research and Development', datetime.datetime(2008, 5, 25, 0, 0), None),
#  (2, 'Tool Design', 'Research and Development', datetime.datetime(2008, 5, 15, 0, 0), None),
#  (3, 'Sales', 'Sales and Marketing', datetime.datetime(2008, 4, 26, 0, 0), None),
#  (4, 'Marketing', 'Sales and Marketing', datetime.datetime(2008, 4, 27, 0, 0), None),
#  (5, 'Purchasing', 'Inventory Management', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (6, 'Research and Development', 'Research and Development', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (7, 'Production', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (8, 'Production Control', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (9, 'Human Resources', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (10, 'Finance', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (11, 'Information Services', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (12, 'Document Control', 'Quality Assurance', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (13, 'Quality Assurance', 'Quality Assurance', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (14, 'Facilities and Maintenance', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (15, 'Shipping and Receiving', 'Inventory Management', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (16, 'Executive', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (17, 'Ingeniería', 'Desarrollo', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (18, 'Engineering', 'CAMBIOS', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (19, 'Engineering', 'ALA ESTE', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (20, 'Engineering', 'ALA OESTE', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (21, 'Engineering', 'ALA SUR', datetime.datetime(2008, 6, 30, 0, 0), None)]

# %%
# Another way to query
with engine.connect() as connect:
    result = connect.execute(db.text('select * from departments'))
    print(result.all())
# Out:
# [(1, 'Engineering', 'Research and Development', datetime.datetime(2008, 5, 25, 0, 0), None), (2, 'Tool Design', 'Research and Development', datetime.datetime(2008, 5, 15, 0, 0), None), (3, 'Sales', 'Sales and Marketing', datetime.datetime(2008, 4, 26, 0, 0), None), (4, 'Marketing', 'Sales and Marketing', datetime.datetime(2008, 4, 27, 0, 0), None), (5, 'Purchasing', 'Inventory Management', datetime.datetime(2008, 4, 30, 0, 0), None), (6, 'Research and Development', 'Research and Development', datetime.datetime(2008, 4, 30, 0, 0), None), (7, 'Production', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None), (8, 'Production Control', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None), (9, 'Human Resources', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None), (10, 'Finance', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None), (11, 'Information Services', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None), (12, 'Document Control', 'Quality Assurance', datetime.datetime(2008, 4, 30, 0, 0), None), (13, 'Quality Assurance', 'Quality Assurance', datetime.datetime(2008, 4, 30, 0, 0), None), (14, 'Facilities and Maintenance', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None), (15, 'Shipping and Receiving', 'Inventory Management', datetime.datetime(2008, 4, 30, 0, 0), None), (16, 'Executive', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None), (17, 'Ingeniería', 'Desarrollo', datetime.datetime(2008, 5, 30, 0, 0), None), (18, 'Engineering', 'CAMBIOS', datetime.datetime(2008, 5, 30, 0, 0), None), (19, 'Engineering', 'ALA ESTE', datetime.datetime(2008, 5, 30, 0, 0), None), (20, 'Engineering', 'ALA OESTE', datetime.datetime(2008, 5, 30, 0, 0), None), (21, 'Engineering', 'ALA SUR', datetime.datetime(2008, 6, 30, 0, 0), None)]

# %%
type(result)
# Out:
# sqlalchemy.engine.cursor.LegacyCursorResult

# %%
# Using pandas API to query
pd.read_sql(sql='select * from departments', con=conn)
# Out:
#     DepartmentID                        Name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
# 16            17                  Ingeniería
# 17            18                 Engineering
# 18            19                 Engineering
# 19            20                 Engineering
# 20            21                 Engineering
#
#                                GroupName ModifiedDate LASTMONTHDATEV3
# 0               Research and Development   2008-05-25            None
# 1               Research and Development   2008-05-15            None
# 2                    Sales and Marketing   2008-04-26            None
# 3                    Sales and Marketing   2008-04-27            None
# 4                   Inventory Management   2008-04-30            None
# 5               Research and Development   2008-04-30            None
# 6                          Manufacturing   2008-04-30            None
# 7                          Manufacturing   2008-04-30            None
# 8   Executive General and Administration   2008-04-30            None
# 9   Executive General and Administration   2008-04-30            None
# 10  Executive General and Administration   2008-04-30            None
# 11                     Quality Assurance   2008-04-30            None
# 12                     Quality Assurance   2008-04-30            None
# 13  Executive General and Administration   2008-04-30            None
# 14                  Inventory Management   2008-04-30            None
# 15  Executive General and Administration   2008-04-30            None
# 16                            Desarrollo   2008-05-30            None
# 17                               CAMBIOS   2008-05-30            None
# 18                              ALA ESTE   2008-05-30            None
# 19                             ALA OESTE   2008-05-30            None
# 20                               ALA SUR   2008-06-30            None

# %%
# Define the metadata of objects, in the future this should be imported
departments = db.schema.Table(
    'departments',
    metadata,
    db.Column('departmentid', db.SMALLINT),
    db.Column('name', db.NVARCHAR(50)), 
    db.Column('groupname', db.NVARCHAR(50)), 
    db.Column('modifieddate', db.DateTime), 
    db.Column('lastmonthdatev3', db.DateTime)
)

# %%
# Automatic metadata import
products = db.schema.Table(
    'products', 
    metadata, 
    autoload=True, 
    autoload_with=engine
)

# %%
# testing the metadata object
for i in metadata.sorted_tables:
    print(i.name)
# Out:
# departments
# products

# %%
print(products.columns.keys())
# Out:
# ['ProductID', 'ProductName', 'SupplierID', 'CategoryID', 'QuantityPerUnit', 'UnitPrice', 'UnitsInStock', 'UnitsOnOrder', 'ReorderLevel', 'Discontinued']

# %%
print(departments.columns.keys())
# Out:
# ['departmentid', 'name', 'groupname', 'modifieddate', 'lastmonthdatev3']

# %%
departments.c.groupname
# Out:
# Column('groupname', NVARCHAR(length=50), table=<departments>)

# %%
# query = db.select(departments).where(departments = '')
# query = db.sql.expression.Select([departments])#.where(departments.c.groupname=='Manufacturing')
query = departments.select().where(departments.c.groupname=='Manufacturing')
resultcursor = conn.execute(query)
resultcursor.fetchall()
# Out:
# [(7, 'Production', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (8, 'Production Control', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None)]

# %%
# SELECT using pandas API 
# pd.read_sql(sql=query, con=conn)
df_query_test = pd.read_sql(query, conn)
df_query_test
# Out:
#    departmentid                name      groupname modifieddate  \
# 0             7          Production  Manufacturing   2008-04-30
# 1             8  Production Control  Manufacturing   2008-04-30
#
#   lastmonthdatev3
# 0            None
# 1            None

# %%
df_query_test.loc[df_query_test['departmentid'] == '8']
# Out:
# Empty DataFrame
# Columns: [departmentid, name, groupname, modifieddate, lastmonthdatev3]
# Index: []

# %% [markdown]
# It outputs nothing, let's check the column's type

# %%
df_query_test.dtypes
# Out:
# departmentid                int64
# name                       object
# groupname                  object
# modifieddate       datetime64[ns]
# lastmonthdatev3            object
# dtype: object

# %%
departments.columns.lastmonthdatev3
# Out:
# Column('lastmonthdatev3', DateTime(), table=<departments>)

# %% [markdown]
# The departmentid column is an integer that's why the .loc method wasn't working

# %%
df_query_test.loc[df_query_test['departmentid'] == 7]
# Out:
#    departmentid        name      groupname modifieddate lastmonthdatev3
# 0             7  Production  Manufacturing   2008-04-30            None

# %%
df_query_test['name'].loc[df_query_test['departmentid'] == 8]
# Out:
# 1    Production Control
# Name: name, dtype: object

# %%
# Change the dataframe 
df_query_test['departmentid'] = df_query_test['departmentid'] + 100

# %%
get_date = date.date.today().isoformat()

# %%
get_date_month = date.date.today().month

# %%
df_query_test[['modifieddate', 'lastmonthdatev3']] = [get_date, get_date_month ]
df_query_test
# Out:
#    departmentid                name      groupname modifieddate  \
# 0           107          Production  Manufacturing   2023-06-16
# 1           108  Production Control  Manufacturing   2023-06-16
#
#    lastmonthdatev3
# 0                6
# 1                6

# %%
df_query_test.to_sql('departments', con=conn,if_exists='append', index=False )
# Out:
# -1

# %% [markdown]
# It outputted -1 but it worked, let's check the table

# %%
pd.read_sql('select * from departments', conn)
# Out:
#     DepartmentID                        Name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
# 16            17                  Ingeniería
# 17            18                 Engineering
# 18            19                 Engineering
# 19            20                 Engineering
# 20            21                 Engineering
# 21           107                  Production
# 22           108          Production Control
#
#                                GroupName ModifiedDate LASTMONTHDATEV3
# 0               Research and Development   2008-05-25             NaT
# 1               Research and Development   2008-05-15             NaT
# 2                    Sales and Marketing   2008-04-26             NaT
# 3                    Sales and Marketing   2008-04-27             NaT
# 4                   Inventory Management   2008-04-30             NaT
# 5               Research and Development   2008-04-30             NaT
# 6                          Manufacturing   2008-04-30             NaT
# 7                          Manufacturing   2008-04-30             NaT
# 8   Executive General and Administration   2008-04-30             NaT
# 9   Executive General and Administration   2008-04-30             NaT
# 10  Executive General and Administration   2008-04-30             NaT
# 11                     Quality Assurance   2008-04-30             NaT
# 12                     Quality Assurance   2008-04-30             NaT
# 13  Executive General and Administration   2008-04-30             NaT
# 14                  Inventory Management   2008-04-30             NaT
# 15  Executive General and Administration   2008-04-30             NaT
# 16                            Desarrollo   2008-05-30             NaT
# 17                               CAMBIOS   2008-05-30             NaT
# 18                              ALA ESTE   2008-05-30             NaT
# 19                             ALA OESTE   2008-05-30             NaT
# 20                               ALA SUR   2008-06-30             NaT
# 21                         Manufacturing   2023-06-16      1900-01-07
# 22                         Manufacturing   2023-06-16      1900-01-07

# %% [markdown]
# The column lastmonthdatev3 was datetime not integer

# %%
departments.update().where(departments.columns.departmentid == 107).values(lastmonthdatev3 = get_date)

# %% [markdown]
# It outputted <sqlalchemy.sql.dml.Update object at 0x000002377AD85910>, let's check the table again

# %%
conn.execute(departments.select()).fetchall()
# Out:
# [(1, 'Engineering', 'Research and Development', datetime.datetime(2008, 5, 25, 0, 0), None),
#  (2, 'Tool Design', 'Research and Development', datetime.datetime(2008, 5, 15, 0, 0), None),
#  (3, 'Sales', 'Sales and Marketing', datetime.datetime(2008, 4, 26, 0, 0), None),
#  (4, 'Marketing', 'Sales and Marketing', datetime.datetime(2008, 4, 27, 0, 0), None),
#  (5, 'Purchasing', 'Inventory Management', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (6, 'Research and Development', 'Research and Development', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (7, 'Production', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (8, 'Production Control', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (9, 'Human Resources', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (10, 'Finance', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (11, 'Information Services', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (12, 'Document Control', 'Quality Assurance', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (13, 'Quality Assurance', 'Quality Assurance', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (14, 'Facilities and Maintenance', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (15, 'Shipping and Receiving', 'Inventory Management', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (16, 'Executive', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (17, 'Ingeniería', 'Desarrollo', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (18, 'Engineering', 'CAMBIOS', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (19, 'Engineering', 'ALA ESTE', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (20, 'Engineering', 'ALA OESTE', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (21, 'Engineering', 'ALA SUR', datetime.datetime(2008, 6, 30, 0, 0), None),
#  (107, 'Production', 'Manufacturing', datetime.datetime(2023, 6, 16, 0, 0), datetime.datetime(1900, 1, 7, 0, 0)),
#  (108, 'Production Control', 'Manufacturing', datetime.datetime(2023, 6, 16, 0, 0), datetime.datetime(1900, 1, 7, 0, 0))]

# %% [markdown]
# It didn't work, need to check this more slowly
#
# Let's try an "executemany" update from

# %%
update_query = (
    db.update(departments)
    .where(departments.c.departmentid == db.bindparam('id'))
    .values(lastmonthdatev3 = db.bindparam('new_date'))
)
with engine.begin() as connection_multi:
    connection_multi.execute(
        update_query, 
        [{'id': 107, 'new_date': get_date},
        {'id': 108, 'new_date': get_date}])

# %% [markdown]
# No output, just a green check, let's check the table again

# %%
conn.execute(departments.select()).fetchmany(25)
# Out:
# [(1, 'Engineering', 'Research and Development', datetime.datetime(2008, 5, 25, 0, 0), None),
#  (2, 'Tool Design', 'Research and Development', datetime.datetime(2008, 5, 15, 0, 0), None),
#  (3, 'Sales', 'Sales and Marketing', datetime.datetime(2008, 4, 26, 0, 0), None),
#  (4, 'Marketing', 'Sales and Marketing', datetime.datetime(2008, 4, 27, 0, 0), None),
#  (5, 'Purchasing', 'Inventory Management', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (6, 'Research and Development', 'Research and Development', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (7, 'Production', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (8, 'Production Control', 'Manufacturing', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (9, 'Human Resources', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (10, 'Finance', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (11, 'Information Services', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (12, 'Document Control', 'Quality Assurance', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (13, 'Quality Assurance', 'Quality Assurance', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (14, 'Facilities and Maintenance', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (15, 'Shipping and Receiving', 'Inventory Management', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (16, 'Executive', 'Executive General and Administration', datetime.datetime(2008, 4, 30, 0, 0), None),
#  (17, 'Ingeniería', 'Desarrollo', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (18, 'Engineering', 'CAMBIOS', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (19, 'Engineering', 'ALA ESTE', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (20, 'Engineering', 'ALA OESTE', datetime.datetime(2008, 5, 30, 0, 0), None),
#  (21, 'Engineering', 'ALA SUR', datetime.datetime(2008, 6, 30, 0, 0), None),
#  (107, 'Production', 'Manufacturing', datetime.datetime(2023, 6, 16, 0, 0), datetime.datetime(2023, 6, 16, 0, 0)),
#  (108, 'Production Control', 'Manufacturing', datetime.datetime(2023, 6, 16, 0, 0), datetime.datetime(2023, 6, 16, 0, 0))]

# %% [markdown]
# ### IT **WORKED**

# %%
# Now in a prettier way
pd.read_sql(departments.select(), conn)
# Out:
#     departmentid                        name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
# 16            17                  Ingeniería
# 17            18                 Engineering
# 18            19                 Engineering
# 19            20                 Engineering
# 20            21                 Engineering
# 21           107                  Production
# 22           108          Production Control
#
#                                groupname modifieddate lastmonthdatev3
# 0               Research and Development   2008-05-25             NaT
# 1               Research and Development   2008-05-15             NaT
# 2                    Sales and Marketing   2008-04-26             NaT
# 3                    Sales and Marketing   2008-04-27             NaT
# 4                   Inventory Management   2008-04-30             NaT
# 5               Research and Development   2008-04-30             NaT
# 6                          Manufacturing   2008-04-30             NaT
# 7                          Manufacturing   2008-04-30             NaT
# 8   Executive General and Administration   2008-04-30             NaT
# 9   Executive General and Administration   2008-04-30             NaT
# 10  Executive General and Administration   2008-04-30             NaT
# 11                     Quality Assurance   2008-04-30             NaT
# 12                     Quality Assurance   2008-04-30             NaT
# 13  Executive General and Administration   2008-04-30             NaT
# 14                  Inventory Management   2008-04-30             NaT
# 15  Executive General and Administration   2008-04-30             NaT
# 16                            Desarrollo   2008-05-30             NaT
# 17                               CAMBIOS   2008-05-30             NaT
# 18                              ALA ESTE   2008-05-30             NaT
# 19                             ALA OESTE   2008-05-30             NaT
# 20                               ALA SUR   2008-06-30             NaT
# 21                         Manufacturing   2023-06-16      2023-06-16
# 22                         Manufacturing   2023-06-16      2023-06-16

# %% [markdown]
# now delete the two new entries

# %%
db.delete(departments).where(departments.c.departmentid.in_([107,108]))

# %%
# Now in a prettier way
pd.read_sql(departments.select(), conn)
# Out:
#     departmentid                        name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
# 16            17                  Ingeniería
# 17            18                 Engineering
# 18            19                 Engineering
# 19            20                 Engineering
# 20            21                 Engineering
# 21           107                  Production
# 22           108          Production Control
#
#                                groupname modifieddate lastmonthdatev3
# 0               Research and Development   2008-05-25             NaT
# 1               Research and Development   2008-05-15             NaT
# 2                    Sales and Marketing   2008-04-26             NaT
# 3                    Sales and Marketing   2008-04-27             NaT
# 4                   Inventory Management   2008-04-30             NaT
# 5               Research and Development   2008-04-30             NaT
# 6                          Manufacturing   2008-04-30             NaT
# 7                          Manufacturing   2008-04-30             NaT
# 8   Executive General and Administration   2008-04-30             NaT
# 9   Executive General and Administration   2008-04-30             NaT
# 10  Executive General and Administration   2008-04-30             NaT
# 11                     Quality Assurance   2008-04-30             NaT
# 12                     Quality Assurance   2008-04-30             NaT
# 13  Executive General and Administration   2008-04-30             NaT
# 14                  Inventory Management   2008-04-30             NaT
# 15  Executive General and Administration   2008-04-30             NaT
# 16                            Desarrollo   2008-05-30             NaT
# 17                               CAMBIOS   2008-05-30             NaT
# 18                              ALA ESTE   2008-05-30             NaT
# 19                             ALA OESTE   2008-05-30             NaT
# 20                               ALA SUR   2008-06-30             NaT
# 21                         Manufacturing   2023-06-16      2023-06-16
# 22                         Manufacturing   2023-06-16      2023-06-16

# %% [markdown]
# Didnt work, need to get more insights in the where clause

# %%
# Making the delete clause
delete_query = db.delete(departments).where(departments.c.departmentid.in_([107,108]))
conn.execute(delete_query)

# %%
# Now in a prettier way
pd.read_sql(departments.select(), conn)
# Out:
#     departmentid                        name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
# 16            17                  Ingeniería
# 17            18                 Engineering
# 18            19                 Engineering
# 19            20                 Engineering
# 20            21                 Engineering
#
#                                groupname modifieddate lastmonthdatev3
# 0               Research and Development   2008-05-25            None
# 1               Research and Development   2008-05-15            None
# 2                    Sales and Marketing   2008-04-26            None
# 3                    Sales and Marketing   2008-04-27            None
# 4                   Inventory Management   2008-04-30            None
# 5               Research and Development   2008-04-30            None
# 6                          Manufacturing   2008-04-30            None
# 7                          Manufacturing   2008-04-30            None
# 8   Executive General and Administration   2008-04-30            None
# 9   Executive General and Administration   2008-04-30            None
# 10  Executive General and Administration   2008-04-30            None
# 11                     Quality Assurance   2008-04-30            None
# 12                     Quality Assurance   2008-04-30            None
# 13  Executive General and Administration   2008-04-30            None
# 14                  Inventory Management   2008-04-30            None
# 15  Executive General and Administration   2008-04-30            None
# 16                            Desarrollo   2008-05-30            None
# 17                               CAMBIOS   2008-05-30            None
# 18                              ALA ESTE   2008-05-30            None
# 19                             ALA OESTE   2008-05-30            None
# 20                               ALA SUR   2008-06-30            None

# %% [markdown]
# Found out what happened, i was creating the statements but never commited them, need to remember to call the engine.execute() method
